# %%
library(ggplot2)
library(tidyverse)
install.packages("Hmisc")
library("Hmisc")
install.packages("psych")
library(psych)
install.packages("lmtest")
library(lmtest)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ tibble  3.0.3     ✔ dplyr   1.0.2
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
# ✔ purrr   0.3.4
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
n <- 150 
x  <-  sample(1:100,150,replace=T)
u  <-  rnorm(n, 0, 10)
y  <-  0.7 * x+u
df <- data.frame(x,y)
df %>% ggplot(aes(x=x,y=y)) + geom_point() + geom_smooth(method='lm')
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
summary(lm(y~x))
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -19.0483  -6.8965   0.4163   5.4908  25.7086
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) -0.13024    1.46626  -0.089    0.929
# x            0.68513    0.02465  27.797   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.302 on 148 degrees of freedom
# Multiple R-squared:  0.8393,	Adjusted R-squared:  0.8382
# F-statistic: 772.7 on 1 and 148 DF,  p-value: < 2.2e-16

# %%
x  <-  rnorm(n,10, 15)
u  <-  rnorm(n, 0, 10)
y  <-  0.7 * x+u
df <- data.frame(x,y)
df %>% ggplot(aes(x=x,y=y)) + geom_point() + geom_smooth(method='lm')
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
summary(lm(y~x))
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -28.1443  -7.1991  -0.8112   7.6657  22.4434
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.18732    1.00159   0.187    0.852
# x            0.75383    0.05461  13.803   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 10.23 on 148 degrees of freedom
# Multiple R-squared:  0.5628,	Adjusted R-squared:  0.5598
# F-statistic: 190.5 on 1 and 148 DF,  p-value: < 2.2e-16

# %%
n <- 2500 
x  <-  rexp(n,5)
u  <-  rnorm(n, 0, 10)
y  <-  7+5*x+u
df <- data.frame(x,y)
df %>% ggplot(aes(x=x,y=y))  +   geom_point(alpha=0.2)  + geom_smooth(method='lm') + 
  geom_smooth(method = "loess", color="red")
# Out:
# `geom_smooth()` using formula 'y ~ x'
#
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
summary(lm(y~x))
# Out:
# Call:
# lm(formula = y ~ x)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -35.445  -6.631  -0.029   6.213  32.351
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   7.3334     0.2774  26.436  < 2e-16 ***
# x             3.9604     0.9619   4.117 3.96e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.88 on 2498 degrees of freedom
# Multiple R-squared:  0.006741,	Adjusted R-squared:  0.006343
# F-statistic: 16.95 on 1 and 2498 DF,  p-value: 3.955e-05

# %%
# df <- data.frame(x,y)
# temp_var <- predict(lm(y~x), interval="prediction")
# df <- cbind(df, temp_var)

# %%
df <- read.csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/csv/AER/CigarettesB.csv', row.names = 1)

# %%
head(df)
# Out:
#    packs   price   income
# AL 4.96213 0.20487 4.64039
# AZ 4.66312 0.16640 4.68389
# AR 5.10709 0.23406 4.59435
# CA 4.50449 0.36399 4.88147
# CT 4.66983 0.32149 5.09472
# DE 5.04705 0.21929 4.87087

# %%
dim(df)
# Out:
# [1] 46  3

# %%
df %>% ggplot(aes(y=packs, x=price)) + 
  geom_point() + geom_smooth(method = 'lm')
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
df %>% ggplot(aes(y=packs, x=income)) + 
  geom_point() + geom_smooth(method = 'lm')
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
df['lgpi'] <- df['income'] - df ['price']

# %%
head(df)
# Out:
#    packs   price   income  lgpi
# AL 4.96213 0.20487 4.64039 4.43552
# AZ 4.66312 0.16640 4.68389 4.51749
# AR 5.10709 0.23406 4.59435 4.36029
# CA 4.50449 0.36399 4.88147 4.51748
# CT 4.66983 0.32149 5.09472 4.77323
# DE 5.04705 0.21929 4.87087 4.65158

# %%
pairs(df, pch = 19)
# Out:
# plot without title

# %%
pairs.panels(df, 
             method = "pearson", # correlation method
             hist.col = "#00AFBB",
             lm = T,
             density = TRUE,  # show density plots
             ellipses = F # show correlation ellipses
             )
# Out:
# plot without title

# %%
mod <- lm(packs~price+income, data = df)
summary(mod)
# Out:
# Call:
# lm(formula = packs ~ price + income, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41867 -0.10683  0.00757  0.11738  0.32868
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.2997     0.9089   4.730 2.43e-05 ***
# price        -1.3383     0.3246  -4.123 0.000168 ***
# income        0.1724     0.1968   0.876 0.385818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1634 on 43 degrees of freedom
# Multiple R-squared:  0.3037,	Adjusted R-squared:  0.2713
# F-statistic: 9.378 on 2 and 43 DF,  p-value: 0.0004168

# %%
mod <- lm(packs~price+income+lgpi, data = df)
summary(mod)
# Out:
# Call:
# lm(formula = packs ~ price + income + lgpi, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41867 -0.10683  0.00757  0.11738  0.32868
#
# Coefficients: (1 not defined because of singularities)
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.2997     0.9089   4.730 2.43e-05 ***
# price        -1.3383     0.3246  -4.123 0.000168 ***
# income        0.1724     0.1968   0.876 0.385818
# lgpi              NA         NA      NA       NA
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1634 on 43 degrees of freedom
# Multiple R-squared:  0.3037,	Adjusted R-squared:  0.2713
# F-statistic: 9.378 on 2 and 43 DF,  p-value: 0.0004168

# %%
cor(df, method='pearson')
# Out:
#        packs      price      income     lgpi
# packs   1.0000000 -0.5397069 -0.1686728  0.1805228
# price  -0.5397069  1.0000000  0.4923318 -0.1296508
# income -0.1686728  0.4923318  1.0000000  0.7992299
# lgpi    0.1805228 -0.1296508  0.7992299  1.0000000

# %%
rcorr(as.matrix(df))
# Out:
#        packs price income  lgpi
# packs   1.00 -0.54  -0.17  0.18
# price  -0.54  1.00   0.49 -0.13
# income -0.17  0.49   1.00  0.80
# lgpi    0.18 -0.13   0.80  1.00
#
# n= 46
#
#
# P
#        packs  price  income lgpi
# packs         0.0001 0.2625 0.2299
# price  0.0001        0.0005 0.3905
# income 0.2625 0.0005        0.0000
# lgpi   0.2299 0.3905 0.0000

# %%
mod <- lm(packs~price+income, data = df)
summary(mod)
# Out:
# Call:
# lm(formula = packs ~ price + income, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41867 -0.10683  0.00757  0.11738  0.32868
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.2997     0.9089   4.730 2.43e-05 ***
# price        -1.3383     0.3246  -4.123 0.000168 ***
# income        0.1724     0.1968   0.876 0.385818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1634 on 43 degrees of freedom
# Multiple R-squared:  0.3037,	Adjusted R-squared:  0.2713
# F-statistic: 9.378 on 2 and 43 DF,  p-value: 0.0004168

# %%
mod <- lm(packs~price+income, data = exp(df))
summary(mod)
# Out:
# Call:
# lm(formula = packs ~ price + income, data = exp(df))
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -47.23 -14.90  -0.47  14.41  50.94
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  291.2090    38.0066   7.662 1.43e-09 ***
# price       -144.1001    35.2302  -4.090 0.000186 ***
# income         0.1353     0.2110   0.642 0.524591
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 21.71 on 43 degrees of freedom
# Multiple R-squared:  0.3097,	Adjusted R-squared:  0.2776
# F-statistic: 9.647 on 2 and 43 DF,  p-value: 0.0003458

# %%
mod <- lm(log(packs)~price+income, data = exp(df))
summary(mod)
# Out:
# Call:
# lm(formula = log(packs) ~ price + income, data = exp(df))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.43318 -0.11345  0.00459  0.12328  0.31498
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  6.007235   0.289474  20.752  < 2e-16 ***
# price       -1.048345   0.268328  -3.907 0.000326 ***
# income       0.001109   0.001607   0.690 0.493841
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1653 on 43 degrees of freedom
# Multiple R-squared:  0.2874,	Adjusted R-squared:  0.2542
# F-statistic:  8.67 on 2 and 43 DF,  p-value: 0.0006865

# %%
mod <- lm(packs~log(price)+income, data = exp(df))
summary(mod)
# Out:
# Call:
# lm(formula = packs ~ log(price) + income, data = exp(df))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -46.547 -14.536   0.074  14.990  45.889
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  150.3593    22.1372   6.792 2.58e-08 ***
# log(price)  -181.7114    42.4574  -4.280 0.000103 ***
# income         0.1401     0.2072   0.676 0.502372
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 21.43 on 43 degrees of freedom
# Multiple R-squared:  0.3276,	Adjusted R-squared:  0.2963
# F-statistic: 10.47 on 2 and 43 DF,  p-value: 0.0001968

# %%
head(exp(df))
# Out:
#    packs     price    income
# AL 142.89784 1.227365 103.58474
# AZ 105.96618 1.181045 108.19011
# AR 165.18895 1.263720  98.92381
# CA  90.42222 1.439060 131.82430
# CT 106.67961 1.379181 163.15815
# DE 155.56288 1.245192 130.43435

# %%
summary(lm(packs~price+income, data=exp(df)))
# Out:
# Call:
# lm(formula = packs ~ price + income, data = exp(df))
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -47.23 -14.90  -0.47  14.41  50.94
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  291.2090    38.0066   7.662 1.43e-09 ***
# price       -144.1001    35.2302  -4.090 0.000186 ***
# income         0.1353     0.2110   0.642 0.524591
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 21.71 on 43 degrees of freedom
# Multiple R-squared:  0.3097,	Adjusted R-squared:  0.2776
# F-statistic: 9.647 on 2 and 43 DF,  p-value: 0.0003458

# %% [markdown]
# $y_i = \beta_1 + \beta_2* x_i+ u_i$

# %% [markdown]
# $\dfrac{dy_i}{dx_i} = \beta_2$

# %%
summary(lm(packs~price+income, data=df))
# Out:
# Call:
# lm(formula = packs ~ price + income, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41867 -0.10683  0.00757  0.11738  0.32868
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.2997     0.9089   4.730 2.43e-05 ***
# price        -1.3383     0.3246  -4.123 0.000168 ***
# income        0.1724     0.1968   0.876 0.385818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1634 on 43 degrees of freedom
# Multiple R-squared:  0.3037,	Adjusted R-squared:  0.2713
# F-statistic: 9.378 on 2 and 43 DF,  p-value: 0.0004168

# %% [markdown]
# $log(y_i) = \beta_1 + \beta_2* log(x_i) + u_i$

# %% [markdown]
# $\dfrac{d \ln y_i}{d \ln x_i} = \beta_2$

# %% [markdown]
# $\dfrac{100 * d y_i / y_i}{100 * d  x_i / x_i} = \beta_2$

# %%
summary(lm(packs~log(price)+income, data=exp(df)))
# Out:
# Call:
# lm(formula = packs ~ log(price) + income, data = exp(df))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -46.547 -14.536   0.074  14.990  45.889
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  150.3593    22.1372   6.792 2.58e-08 ***
# log(price)  -181.7114    42.4574  -4.280 0.000103 ***
# income         0.1401     0.2072   0.676 0.502372
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 21.43 on 43 degrees of freedom
# Multiple R-squared:  0.3276,	Adjusted R-squared:  0.2963
# F-statistic: 10.47 on 2 and 43 DF,  p-value: 0.0001968

# %% [markdown]
# $y_i = \beta_1 + \beta_2* log(x_i) + u_i$

# %% [markdown]
# $\dfrac{d y_i}{d \ln x_i} = \beta_2$

# %% [markdown]
# $\dfrac{d y_i }{100 *  d  x_i / x_i} = \beta_2 / 100 $

# %%
summary(lm(log(packs)~price+income, data=exp(df)))
# Out:
# Call:
# lm(formula = log(packs) ~ price + income, data = exp(df))
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.43318 -0.11345  0.00459  0.12328  0.31498
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  6.007235   0.289474  20.752  < 2e-16 ***
# price       -1.048345   0.268328  -3.907 0.000326 ***
# income       0.001109   0.001607   0.690 0.493841
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1653 on 43 degrees of freedom
# Multiple R-squared:  0.2874,	Adjusted R-squared:  0.2542
# F-statistic:  8.67 on 2 and 43 DF,  p-value: 0.0006865

# %% [markdown]
# $log(y_i) = \beta_1 + \beta_2* x_i + u_i$

# %% [markdown]
# $\dfrac{100 * d y_i / y_i}{d  x_i } = 100 * \beta_2$

# %% [markdown]
# ### Hypothesis testing and confidence intervals

# %%
mod <- lm(packs~price+income, data = df)
summary(mod)
# Out:
# Call:
# lm(formula = packs ~ price + income, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41867 -0.10683  0.00757  0.11738  0.32868
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.2997     0.9089   4.730 2.43e-05 ***
# price        -1.3383     0.3246  -4.123 0.000168 ***
# income        0.1724     0.1968   0.876 0.385818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1634 on 43 degrees of freedom
# Multiple R-squared:  0.3037,	Adjusted R-squared:  0.2713
# F-statistic: 9.378 on 2 and 43 DF,  p-value: 0.0004168

# %%
coeftest(mod)
# Out:
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  4.29966    0.90893  4.7305 2.434e-05 ***
# price       -1.33833    0.32460 -4.1230 0.0001676 ***
# income       0.17239    0.19675  0.8761 0.3858180
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
coeftest(mod, df = Inf)
# Out:
# z test of coefficients:
#
#             Estimate Std. Error z value Pr(>|z|)
# (Intercept)  4.29966    0.90893  4.7305 2.24e-06 ***
# price       -1.33833    0.32460 -4.1230 3.74e-05 ***
# income       0.17239    0.19675  0.8761   0.3809
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# install.packages("sandwich")
# library(sandwich)
# coeftest(mod, vcov=vcovHC, type = "HC3")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
# t test of coefficients:
#
#             Estimate Std. Error t value  Pr(>|t|)
# (Intercept)  4.29966    1.16133  3.7024 0.0006039 ***
# price       -1.33833    0.37945 -3.5270 0.0010136 **
# income       0.17239    0.25133  0.6859 0.4964695
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
confint(mod)
# confint(mod, df=Inf, vcov=vcovHC, type = "HC3")
# Out:
#             2.5 %      97.5 %
# (Intercept)  2.4666383  6.1326851
# price       -1.9929561 -0.6837136
# income      -0.2244071  0.5691790

# %%
## note that the degrees of freedom _actually used_ can be extracted
df.residual(ct)
## which differ here from
df.residual(mod)

df.residual(coeftest(mod, df = Inf))
# Out:
# [1] 43
# [1] 43
# [1] Inf

# %% [markdown]
# ### Multicollinearity

# %%
df['logpi'] = df['income'] - df['price']

# %%
summary(lm(packs~price+logpi, data=df))
summary(lm(packs~price+income, data=df))
# Out:
# Call:
# lm(formula = packs ~ price + logpi, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41867 -0.10683  0.00757  0.11738  0.32868
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.2997     0.9089   4.730 2.43e-05 ***
# price        -1.1659     0.2849  -4.092 0.000185 ***
# logpi         0.1724     0.1968   0.876 0.385818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1634 on 43 degrees of freedom
# Multiple R-squared:  0.3037,	Adjusted R-squared:  0.2713
# F-statistic: 9.378 on 2 and 43 DF,  p-value: 0.0004168
# Call:
# lm(formula = packs ~ price + income, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41867 -0.10683  0.00757  0.11738  0.32868
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.2997     0.9089   4.730 2.43e-05 ***
# price        -1.3383     0.3246  -4.123 0.000168 ***
# income        0.1724     0.1968   0.876 0.385818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1634 on 43 degrees of freedom
# Multiple R-squared:  0.3037,	Adjusted R-squared:  0.2713
# F-statistic: 9.378 on 2 and 43 DF,  p-value: 0.0004168

# %%
summary(lm(packs~price+income, data=df))
# Out:
# Call:
# lm(formula = packs ~ price + income, data = df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.41867 -0.10683  0.00757  0.11738  0.32868
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   4.2997     0.9089   4.730 2.43e-05 ***
# price        -1.3383     0.3246  -4.123 0.000168 ***
# income        0.1724     0.1968   0.876 0.385818
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.1634 on 43 degrees of freedom
# Multiple R-squared:  0.3037,	Adjusted R-squared:  0.2713
# F-statistic: 9.378 on 2 and 43 DF,  p-value: 0.0004168

# %% [markdown]
# $$F(k-1, n-k)=\dfrac{ESS/(k-1)}{RSS/(n-k)} = \dfrac{R^2/(k-1)}{(1-R^2)/(n-k)}  $$

# %%
cor(df, method='pearson')
# Out:
#        packs      price      income     logpi
# packs   1.0000000 -0.5397069 -0.1686728  0.1805228
# price  -0.5397069  1.0000000  0.4923318 -0.1296508
# income -0.1686728  0.4923318  1.0000000  0.7992299
# logpi   0.1805228 -0.1296508  0.7992299  1.0000000

# %%
rcorr(as.matrix(df))
# Out:
#        packs price income logpi
# packs   1.00 -0.54  -0.17  0.18
# price  -0.54  1.00   0.49 -0.13
# income -0.17  0.49   1.00  0.80
# logpi   0.18 -0.13   0.80  1.00
#
# n= 46
#
#
# P
#        packs  price  income logpi
# packs         0.0001 0.2625 0.2299
# price  0.0001        0.0005 0.3905
# income 0.2625 0.0005        0.0000
# logpi  0.2299 0.3905 0.0000

# %%
pairs(df)
# Out:
# plot without title

# %%
pairs.panels(df,lm=T, ellipses=F, method = 'pearson')
# Out:
# plot without title
