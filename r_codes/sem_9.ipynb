# %%
# data('food', package='PoEdata')

# %%
load(file='food.rda')

# %%
mod1<-lm(food_exp~income, data=food)
summary(mod1)
# Out:
# Call:
# lm(formula = food_exp ~ income, data = food)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -223.025  -50.816   -6.324   67.879  212.044
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   83.416     43.410   1.922   0.0622 .
# income        10.210      2.093   4.877 1.95e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 89.52 on 38 degrees of freedom
# Multiple R-squared:  0.385,	Adjusted R-squared:  0.3688
# F-statistic: 23.79 on 1 and 38 DF,  p-value: 1.946e-05

# %%
plot(food$income,food$food_exp)
abline(mod1)
# Out:
# plot without title

# %%
plot(log(food$income),log(food$food_exp))
# Out:
# plot without title

# %%
w <- 1/food$income
mod2<-lm(food_exp~income, weight=w, data=food)
summary(mod1)
summary(mod2)
# Out:
# Call:
# lm(formula = food_exp ~ income, data = food)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -223.025  -50.816   -6.324   67.879  212.044
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   83.416     43.410   1.922   0.0622 .
# income        10.210      2.093   4.877 1.95e-05 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 89.52 on 38 degrees of freedom
# Multiple R-squared:  0.385,	Adjusted R-squared:  0.3688
# F-statistic: 23.79 on 1 and 38 DF,  p-value: 1.946e-05
# Call:
# lm(formula = food_exp ~ income, data = food, weights = w)
#
# Weighted Residuals:
#    Min     1Q Median     3Q    Max
# -45.37 -11.13  -1.33  15.02  39.23
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   78.684     23.789   3.308  0.00206 **
# income        10.451      1.386   7.541 4.61e-09 ***
# ---
# ...

# %%
library(lmtest)

# %%
white.test()

# %%
mod1
# Out:
# Call:
# lm(formula = food_exp ~ income, data = food)
#
# Coefficients:
# (Intercept)       income
#       83.42        10.21

# %%
bptest(mod1)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod1
# BP = 7.3844, df = 1, p-value = 0.006579

# %%
bptest(mod2, varformula = ~ w)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod2
# BP = 3.6189, df = 1, p-value = 0.05713

# %%
bptest(summary(mod1)$resid)
# Out:
# Error: $ operator is invalid for atomic vectors
# Traceback:
#
# 1. bptest(summary(mod1)$resid)

# %%
plot(summary(mod1)$resid)
# Out:
# plot without title

# %%
plot(summary(mod2)$resid)
# Out:
# plot without title

# %%
bptest(mod2)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  mod2
# BP = 7.3844, df = 1, p-value = 0.006579
